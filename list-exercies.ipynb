# %% [markdown]
# # This is List_Exercise

# %%
 toys = {"robot": "$40.0", "car": "$25", "ironman": "$12"}

# %%
values=list(toys.values())
int(eval(values[0][1:]) + eval(values[1][1:])+ eval(values[2][1:]))
# Out:
# 77

# %%
questions = [10 != 4, 50 == 50, 90 == 10, "c" in ("a", "b", "c"), 100 != 100]
questions
# Out:
# [True, True, False, True, False]

# %%
films = {"k1": "blade runner 2049", "k2": "matrix", "k3": "terminator"}
len(films["k1"])>len(films["k2"])<len(films["k3"])
# Out:
# True

# %%
life_stages = {0: "embryo", 1: "fetus", 2:"baby", 3:"infant",4: "teen "}
life_stages.update({ 5: 'adult', 6: 'big kid!'})
life_stages
# Out:
# {0: 'embryo',
#  1: 'fetus',
#  2: 'baby',
#  3: 'infant',
#  4: 'teen ',
#  5: 'adult',
#  6: 'big kid!'}

# %%
nest1 = [(1,2,3), {"k1": [8, 1, 300, 2, 77], "k2": [10,20,30]}, ["a", "500", "c"]]
sumresult = nest1[0][-1] + nest1[1]["k1"][2] + nest1[1]["k2"][-1] + eval(nest1[2][1])
print(float(sumresult))
# Out:
# 833.0

# %%
prices = ["a", "b", "9", "c", "d", "FOUR", "e", "f", "2.5"]
sentence = """The bill for the {}#!/,?? {}#!/ ??and drink came to {}??""".format("pizza","chips","2.5")
print(prices[2::3])
sentence.replace("#","").replace("!","").replace("/","").replace("??","")
# Out:
# ['9', 'FOUR', '2.5']
# 'The bill for the pizza, chips and drink came to 2.5'
